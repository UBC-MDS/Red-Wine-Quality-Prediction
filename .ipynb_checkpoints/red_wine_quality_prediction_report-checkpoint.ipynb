# %% [markdown]
# # Red Wine Quality Prediction
#
# authors:

# %% [markdown]
# ## Summary

# %% [markdown]
# ## Introduction

# %% [markdown]
# Red wines have a long history that can be traced all the way back to the ancient Greeks. Today, they are more accessible to an average person than ever and the entire industry is estimated to be worth around 109.5 billion USD, and yet despite its ubiquity, most people can barely tell the difference between a good and a bad wine, to the point where we need trained professionals (sommeliers) to understand the difference. In this project, we seek to use machine learning algorithms to predict the quality of the wine based on the physical and chemical properties of the liquid.  This model could allow for manufactures and suppliers to have a more robust understanding of the quality of the wine based on measurable properties.

# %% [markdown]
# ## EDA

# %%
import pandas as pd 
import numpy as np
import sys
from hashlib import sha1
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.dummy import DummyClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import (
    GridSearchCV,
    RandomizedSearchCV,
    cross_validate,
    train_test_split,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import altair as alt
from sklearn.linear_model import Ridge

# %% [markdown]
# ### Dataset Description
# The dataset which will be used for analysis is the "winequality-red.csv" file from the <a href=https://archive.ics.uci.edu/dataset/186/wine+quality>UC Irvine Machine Learning Repository</a>, which was originally referenced from <a href=http://www3.dsi.uminho.pt/pcortez/wine/>Decision Support Systems, Elsevier</a>. The dataset contains physiochemical proprties (features) of red vinho verde wine samples from the north of Portugal, along with an associated wine quality score from 0 (worst) to 10 (best).

# %%
# Import the dataset:
df = pd.read_csv('data/winequality-red.csv', sep = ';')

# Visualize the first 5 rows:
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# This section is to be deleted after the report is compiled.
# Determine the size of the dataset:
print(df.shape)

# Determine the value counts for each unique target (quality) value::
print(df.quality.unique())
df.quality.value_counts().sort_index()
# Out:
# (1599, 12)
# [5 6 7 4 8 3]
# quality
# 3     10
# 4     53
# 5    681
# 6    638
# 7    199
# 8     18
# Name: count, dtype: int64

# %% [markdown]
# There are 11 feature columns representing physiochemical characteristics of the wines, such as fixed acidity, residual sugar, chlorides, density, etc. There are 1598 rows or observations in the dataset. The target is the quality column which is listed as a set of ordinal values from 3 to 8, although they could go as low as 0 or as high as 10. Most observations have an "average" quality between 5 and 7, with very few observations below a score of 5 or above a score of 7. This shows an unbalanced dataset.

# %%
# View feature dtypes and counts, null values:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# In each of the 11 feature columns above, all entries have non-null values. As a result, imputation is not required to replace the null values. The data types of all features columns are float64 and the target column is int64. Although the target column "quality" is numeric, this problem could be considered as a classification or regression problem, as the numeric targets represent a wine quality category (i.e. from 0 to 10). Lastly, due to the numeric nature of the features preprocessing in the form of StandardScaler() will be required to scale each of the features, to prevent features of a large relative magnitude from dominating features of a smaller relative magnitude.
#
# All 11 features are numeric with no missing values. The response variable is a label for wine quality ranging from 0 to 10. We will treat this as a classification problem for our models.

# %%
# View summary statistics:
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# ### Visualization

# %% [markdown]
# We first observe the distribution of the features using their statistical summaries and a histogram. We can see that the majority of features have a skewed distribution, with many containing outliers. Volatile acidity, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, and sulphates all have very extreme outliers.

# %%
# Features 
feature_df = df.drop('quality', axis=1)

feature_names = list(feature_df.columns)

alt.Chart(feature_df).mark_bar().encode(
     alt.X(alt.repeat()).type('quantitative').bin(maxbins=40),
     y='count()',
).properties(
    width=150,
    height=150
).repeat(
    feature_names, 
    columns=3
)
# Out:
# alt.RepeatChart(...)

# %% [markdown]
# Next we look at potential correlations between the features. The correlation matrix ranges from dark green to indicate a strong positive correlation, white to indicate no correlation and dark pink to indicate a strong negative correlation. The features with the strongest correlations are summarized in the table below.

# %%
feature_df.corr(numeric_only=True).style.background_gradient('PiYG')
# Out:
# <style type="text/css">
# #T_dd075_row0_col0, #T_dd075_row1_col1, #T_dd075_row2_col2, #T_dd075_row3_col3, #T_dd075_row4_col4, #T_dd075_row5_col5, #T_dd075_row6_col6, #T_dd075_row7_col7, #T_dd075_row8_col8, #T_dd075_row9_col9, #T_dd075_row10_col10 {
#   background-color: #276419;
#   color: #f1f1f1;
# }
# #T_dd075_row0_col1, #T_dd075_row9_col1 {
#   background-color: #db6ca8;
#   color: #f1f1f1;
# }
# #T_dd075_row0_col2 {
#   background-color: #86c049;
#   color: #000000;
# }
# #T_dd075_row0_col3, #T_dd075_row4_col10 {
#   background-color: #da69a6;
#   color: #f1f1f1;
# }
# #T_dd075_row0_col4 {
#   background-color: #eeabd2;
#   color: #000000;
# }
# #T_dd075_row0_col5, #T_dd075_row0_col8, #T_dd075_row1_col2, #T_dd075_row1_col9, #T_dd075_row2_col1, #T_dd075_row7_col10, #T_dd075_row8_col0, #T_dd075_row8_col3, #T_dd075_row8_col4, #T_dd075_row10_col6, #T_dd075_row10_col7 {
#   background-color: #8e0152;
#   color: #f1f1f1;
# }
# #T_dd075_row0_col6 {
#   background-color: #b71472;
#   color: #f1f1f1;
# }
# #T_dd075_row0_col7 {
#   background-color: #8ac34f;
#   color: #000000;
# }
# #T_dd075_row0_col9, #T_dd075_row3_col8 {
#   background-color: #f7cce5;
#   color: #000000;
# }
# #T_dd075_row0_col10 {
#   background-color: #efb0d6;
#   color: #000000;
# }
# #T_dd075_row1_col0, #T_dd075_row3_col4, #T_dd075_row5_col3 {
#   background-color: #e897c4;
#   color: #000000;
# }
# #T_dd075_row1_col3, #T_dd075_row2_col5 {
#   background-color: #b91574;
#   color: #f1f1f1;
# }
# #T_dd075_row1_col4 {
#   background-color: #e99cc8;
#   color: #000000;
# }
# #T_dd075_row1_col5 {
#   background-color: #ca2f88;
#   color: #f1f1f1;
# }
# #T_dd075_row1_col6 {
#   background-color: #e48bbc;
#   color: #f1f1f1;
# }
# #T_dd075_row1_col7 {
#   background-color: #f6c9e3;
#   color: #000000;
# }
# #T_dd075_row1_col8 {
#   background-color: #eff6e5;
#   color: #000000;
# }
# #T_dd075_row1_col10 {
#   background-color: #dd73ac;
#   color: #f1f1f1;
# }
# #T_dd075_row2_col0 {
#   background-color: #7bb93e;
#   color: #f1f1f1;
# }
# #T_dd075_row2_col3, #T_dd075_row3_col9, #T_dd075_row5_col4 {
#   background-color: #e07eb3;
#   color: #f1f1f1;
# }
# #T_dd075_row2_col4, #T_dd075_row7_col1, #T_dd075_row7_col4, #T_dd075_row10_col0 {
#   background-color: #f9d3e8;
#   color: #000000;
# }
# #T_dd075_row2_col6, #T_dd075_row7_col8 {
#   background-color: #de77ae;
#   color: #f1f1f1;
# }
# #T_dd075_row2_col7 {
#   background-color: #eaf5d9;
#   color: #000000;
# }
# #T_dd075_row2_col8, #T_dd075_row9_col3 {
#   background-color: #bb1675;
#   color: #f1f1f1;
# }
# #T_dd075_row2_col9 {
#   background-color: #faedf3;
#   color: #000000;
# }
# #T_dd075_row2_col10, #T_dd075_row6_col1, #T_dd075_row7_col3 {
#   background-color: #fde1ef;
#   color: #000000;
# }
# #T_dd075_row3_col0 {
#   background-color: #f9f1f5;
#   color: #000000;
# }
# #T_dd075_row3_col1 {
#   background-color: #f8cee6;
#   color: #000000;
# }
# #T_dd075_row3_col2, #T_dd075_row5_col8 {
#   background-color: #faebf3;
#   color: #000000;
# }
# #T_dd075_row3_col5 {
#   background-color: #f0b2d7;
#   color: #000000;
# }
# #T_dd075_row3_col6, #T_dd075_row6_col0 {
#   background-color: #f5c6e2;
#   color: #000000;
# }
# #T_dd075_row3_col7 {
#   background-color: #ebf6dc;
#   color: #000000;
# }
# #T_dd075_row3_col10 {
#   background-color: #f8d0e7;
#   color: #000000;
# }
# #T_dd075_row4_col0 {
#   background-color: #f9eef4;
#   color: #000000;
# }
# #T_dd075_row4_col1 {
#   background-color: #fddeee;
#   color: #000000;
# }
# #T_dd075_row4_col2 {
#   background-color: #f8f4f6;
#   color: #000000;
# }
# #T_dd075_row4_col3 {
#   background-color: #cc368b;
#   color: #f1f1f1;
# }
# #T_dd075_row4_col5 {
#   background-color: #ce3d8f;
#   color: #f1f1f1;
# }
# #T_dd075_row4_col6 {
#   background-color: #df7cb1;
#   color: #f1f1f1;
# }
# #T_dd075_row4_col7 {
#   background-color: #f9eff4;
#   color: #000000;
# }
# #T_dd075_row4_col8, #T_dd075_row5_col9, #T_dd075_row6_col4 {
#   background-color: #e795c3;
#   color: #000000;
# }
# #T_dd075_row4_col9, #T_dd075_row9_col4 {
#   background-color: #f7f7f6;
#   color: #000000;
# }
# #T_dd075_row5_col0 {
#   background-color: #f3bcdd;
#   color: #000000;
# }
# #T_dd075_row5_col1 {
#   background-color: #f7cbe4;
#   color: #000000;
# }
# #T_dd075_row5_col2, #T_dd075_row5_col7 {
#   background-color: #f3bdde;
#   color: #000000;
# }
# #T_dd075_row5_col6 {
#   background-color: #a9d874;
#   color: #000000;
# }
# #T_dd075_row5_col10, #T_dd075_row9_col8 {
#   background-color: #eeadd4;
#   color: #000000;
# }
# #T_dd075_row6_col2 {
#   background-color: #fad6ea;
#   color: #000000;
# }
# #T_dd075_row6_col3 {
#   background-color: #eba1cb;
#   color: #000000;
# }
# #T_dd075_row6_col5 {
#   background-color: #b0dc7d;
#   color: #000000;
# }
# #T_dd075_row6_col7 {
#   background-color: #fbd8eb;
#   color: #000000;
# }
# #T_dd075_row6_col8 {
#   background-color: #f9d1e8;
#   color: #000000;
# }
# #T_dd075_row6_col9 {
#   background-color: #e590bf;
#   color: #f1f1f1;
# }
# #T_dd075_row6_col10, #T_dd075_row8_col5 {
#   background-color: #dc70aa;
#   color: #f1f1f1;
# }
# #T_dd075_row7_col0 {
#   background-color: #7dba40;
#   color: #f1f1f1;
# }
# #T_dd075_row7_col2 {
#   background-color: #e7f5d3;
#   color: #000000;
# }
# #T_dd075_row7_col5, #T_dd075_row8_col6 {
#   background-color: #c82884;
#   color: #f1f1f1;
# }
# #T_dd075_row7_col6 {
#   background-color: #e388ba;
#   color: #f1f1f1;
# }
# #T_dd075_row7_col9 {
#   background-color: #f4c1df;
#   color: #000000;
# }
# #T_dd075_row8_col1 {
#   background-color: #f6f7f5;
#   color: #000000;
# }
# #T_dd075_row8_col2 {
#   background-color: #900254;
#   color: #f1f1f1;
# }
# #T_dd075_row8_col7 {
#   background-color: #c51d7e;
#   color: #f1f1f1;
# }
# #T_dd075_row8_col9 {
#   background-color: #aa0e68;
#   color: #f1f1f1;
# }
# #T_dd075_row8_col10 {
#   background-color: #f9f0f5;
#   color: #000000;
# }
# #T_dd075_row9_col0 {
#   background-color: #f5f7f2;
#   color: #000000;
# }
# #T_dd075_row9_col2 {
#   background-color: #edf6e1;
#   color: #000000;
# }
# #T_dd075_row9_col5 {
#   background-color: #d861a2;
#   color: #f1f1f1;
# }
# #T_dd075_row9_col6 {
#   background-color: #df79b0;
#   color: #f1f1f1;
# }
# #T_dd075_row9_col7 {
#   background-color: #fbe7f2;
#   color: #000000;
# }
# #T_dd075_row9_col10 {
#   background-color: #fcdded;
#   color: #000000;
# }
# #T_dd075_row10_col1 {
#   background-color: #e286b8;
#   color: #f1f1f1;
# }
# #T_dd075_row10_col2 {
#   background-color: #fbe6f1;
#   color: #000000;
# }
# #T_dd075_row10_col3 {
#   background-color: #c92b86;
#   color: #f1f1f1;
# }
# #T_dd075_row10_col4 {
#   background-color: #9f095f;
#   color: #f1f1f1;
# }
# #T_dd075_row10_col5 {
#   background-color: #b51370;
#   color: #f1f1f1;
# }
# #T_dd075_row10_col8 {
#   background-color: #f2f6ec;
#   color: #000000;
# }
# #T_dd075_row10_col9 {
#   background-color: #eda8d1;
#   color: #000000;
# }
# </style>
# <table id="T_dd075">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd075_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_dd075_level0_col1" class="col_heading level0 col1" >volatile acidity</th>
#       <th id="T_dd075_level0_col2" class="col_heading level0 col2" >citric acid</th>
#       <th id="T_dd075_level0_col3" class="col_heading level0 col3" >residual sugar</th>
#       <th id="T_dd075_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_dd075_level0_col5" class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th id="T_dd075_level0_col6" class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th id="T_dd075_level0_col7" class="col_heading level0 col7" >density</th>
#       <th id="T_dd075_level0_col8" class="col_heading level0 col8" >pH</th>
#       <th id="T_dd075_level0_col9" class="col_heading level0 col9" >sulphates</th>
#       <th id="T_dd075_level0_col10" class="col_heading level0 col10" >alcohol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd075_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_dd075_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_dd075_row0_col1" class="data row0 col1" >-0.256131</td>
#       <td id="T_dd075_row0_col2" class="data row0 col2" >0.671703</td>
#       <td id="T_dd075_row0_col3" class="data row0 col3" >0.114777</td>
#       <td id="T_dd075_row0_col4" class="data row0 col4" >0.093705</td>
#       <td id="T_dd075_row0_col5" class="data row0 col5" >-0.153794</td>
#       <td id="T_dd075_row0_col6" class="data row0 col6" >-0.113181</td>
#       <td id="T_dd075

# %%
# Features with stronger correlations (|correlation coeff| > 0.6)
corr_df = feature_df.corr().unstack().reset_index()
corr_df.columns = ['feature_1', 'feature_2', 'correlation']
corr_top = corr_df[(abs(corr_df['correlation']) > 0.6)]
corr_top = corr_top[corr_top['feature_1'] != corr_top['feature_2']]

# get unique pairings
corr_top[['feature_1', 'feature_2']] = corr_top[['feature_1', 'feature_2']].apply(sorted, axis=1, result_type='expand')
unique_corr_df = corr_top[~corr_top.duplicated(subset=['feature_1', 'feature_2'])]

# display results
display(unique_corr_df)
# Out:
#               feature_1             feature_2  correlation
# 2           citric acid         fixed acidity     0.671703
# 7               density         fixed acidity     0.668047
# 8         fixed acidity                    pH    -0.682978
# 61  free sulfur dioxide  total sulfur dioxide     0.667666

# %% [markdown]
# To reduce model dimensionality and redundancy one of each pair of the highly correlated features can be removed.

# %% [markdown]
# ## Methods

# %%
X = df.drop(columns = ['quality'])
y = df['quality']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 522)

# %%
models1 = {
    "dummy": DummyClassifier(random_state=522), 
    "KNN": KNeighborsClassifier(),
    "RBF SVM": SVC(random_state=123),
    'decision tree': DecisionTreeClassifier(),
}

# %%
from sklearn.compose import make_column_transformer


results1 = []

for name, model in models1.items():
    pipeline =  make_pipeline(StandardScaler(), model) 
    scores = cross_validate(pipeline, X_train, y_train, return_train_score=True, n_jobs=-1)
 #   mean_std_cross_val_scores
    results1.append({
        'model': name,
        'test_score': np.mean(scores['test_score']),
        'train_score': np.mean(scores['train_score']),
        'fit_time': np.mean(scores['fit_time']),
        'score_time': np.mean(scores['score_time'])
    })

results_df1 = pd.DataFrame(results1)
results_df1.set_index('model', inplace=True)
results_df1
# Out:
#                test_score  train_score  fit_time  score_time
# model
# dummy            0.440575     0.440572  0.000000    0.000000
# KNN              0.551381     0.699952  0.001574    0.006899
# RBF SVM          0.605898     0.676940  0.026950    0.004525
# decision tree    0.587972     1.000000  0.009720    0.000778

# %% [markdown]
# # ANALYSIS:
#
# In this study, we employed various machine learning models to predict the quality of wine based on its chemical properties. The models used included a Dummy model, K-Nearest Neighbors (KNN), Support Vector Machine (SVM) with Radial Basis Function (RBF) kernel. These models were rigorously cross-validated with 5 folds to assess their performance. The Python programming language, along with essential packages such as Pandas,scikit-learn was instrumental in conducting this analysis.
#
# The initial performance of each model, as measured by test scores, was as follows:
#
# Dummy Model: 0.437059
# KNN: 0.562917
# RBF SVM: 0.615313
#
# As a result, the best performing model is RBF SVM model and we will do hyperparameter optimization on this model.

# %% [markdown]
# This refined analysis suggests a more focused model, with the reduced feature set enhancing the predictive accuracy of certain models, notably the KNN and Linear SVC. The data utilized for this study encompass various physicochemical properties of wine, such as acidity, sulfur dioxide levels, and alcohol content, which are believed to influence its quality.
# Based on the results, we will focus on decision tree model, RBF SVM, Ridge for hyperparameter optimizations

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
import altair as alt
import matplotlib.pyplot as plt

# %%
#Decision Tree Tuning
pipe_dt = make_pipeline(StandardScaler(), DecisionTreeClassifier())

dt_param_grid = {
    "decisiontreeclassifier__criterion": ['gini', 'entropy'],
    "decisiontreeclassifier__max_depth": 2 ** np.arange(8)
}

dt_gs = GridSearchCV(pipe_dt, param_grid=dt_param_grid, n_jobs=-1, return_train_score=True)

# %%
dt_gs.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('decisiontreeclassifier',
#                                         DecisionTreeClassifier())]),
#              n_jobs=-1,
#              param_grid={'decisiontreeclassifier__criterion': ['gini',
#                                                                'entropy'],
#                          'decisiontreeclassifier__max_depth': array([  1,   2,   4,   8,  16,  32,  64, 128], dtype=int32)},
#              return_train_score=True)

# %%
dt_df = (pd.DataFrame(dt_gs.cv_results_)[
    [
        "mean_test_score",
        "mean_train_score",
        "param_decisiontreeclassifier__criterion",
        "param_decisiontreeclassifier__max_depth",
        "mean_fit_time",
        "rank_test_score",
    ]
].set_index("rank_test_score").sort_index())

# %%
dt_df.head(1)
# Out:
#                  mean_test_score  mean_train_score  \
# rank_test_score
# 1                       0.603211               1.0
#
#                 param_decisiontreeclassifier__criterion  \
# rank_test_score
# 1                                                  gini
#
#                 param_decisiontreeclassifier__max_depth  mean_fit_time
# rank_test_score
# 1                                                    64       0.009509

# %%
plot = alt.Chart(dt_df, title="Validation Score for Different Parameters for Decision Tree").mark_line().encode(x=alt.X('param_decisiontreeclassifier__max_depth', title='max_depth'), 
                                    y=alt.Y('mean_test_score', title='Validation Score').scale(zero=False),
                                    color=alt.Color('param_decisiontreeclassifier__criterion', title='criterion'))
plot + alt.Chart(dt_df.head(1)).mark_text(dy=-5).encode(
    x='param_decisiontreeclassifier__max_depth',
    y="mean_test_score",
    text=alt.value('Max'))
# Out:
# alt.LayerChart(...)

# %%
#Linear SVC Tuning
pipe_lsvc = make_pipeline(StandardScaler(), SVC(kernel = 'linear'))

lsvc_param_grid = {
    "svc__C": [0.001, 0.01, 0.1, 1.0, 10, 100, 1000]
}

lsvc_gs = GridSearchCV(pipe_lsvc, param_grid=lsvc_param_grid, n_jobs=-1, return_train_score=True)

# %%
lsvc_gs.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('svc', SVC(kernel='linear'))]),
#              n_jobs=-1,
#              param_grid={'svc__C': [0.001, 0.01, 0.1, 1.0, 10, 100, 1000]},
#              return_train_score=True)

# %%
lsvc_df = (pd.DataFrame(lsvc_gs.cv_results_)[
    [
        "mean_test_score",
        "mean_train_score",
        "param_svc__C",
        "mean_fit_time",
        "rank_test_score",
    ]
].set_index("rank_test_score").sort_index())

# %%
lsvc_df.head(1)
# Out:
#                  mean_test_score  mean_train_score param_svc__C  mean_fit_time
# rank_test_score
# 1                       0.557707          0.568813          0.1       0.025005

# %%
plot = alt.Chart(lsvc_df, title="Validation Score for Different Parameters for Linear SVM").mark_line().encode(
    x=alt.X('param_svc__C', title='C (log scale)', scale=alt.Scale(type='log')),
    y=alt.Y('mean_test_score', title='Validation Score').scale(zero=False))

plot + alt.Chart(lsvc_df.head(1)).mark_text(dy=-5).encode(
    x='param_svc__C',
    y="mean_test_score",
    text=alt.value('Max'))
# Out:
# alt.LayerChart(...)

# %%
#RBF SVM Tuning
pipe_rbf = make_pipeline(StandardScaler(), SVC(random_state=123))

rbf_param_grid = {
    "svc__gamma": [0.001, 0.01, 0.1, 1.0, 10, 100],
    "svc__C": [0.001, 0.01, 0.1, 1.0, 10, 100]
}

rbf_gs = GridSearchCV(pipe_rbf, param_grid=rbf_param_grid, n_jobs=-1, return_train_score=True)

# %%
rbf_gs.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('svc', SVC(random_state=123))]),
#              n_jobs=-1,
#              param_grid={'svc__C': [0.001, 0.01, 0.1, 1.0, 10, 100],
#                          'svc__gamma': [0.001, 0.01, 0.1, 1.0, 10, 100]},
#              return_train_score=True)

# %%
rbf_df = (pd.DataFrame(rbf_gs.cv_results_)[
    [
        "mean_test_score",
        "mean_train_score",
        "param_svc__gamma",
        "param_svc__C",
        "mean_fit_time",
        "rank_test_score",
    ]
].set_index("rank_test_score").sort_index())

# %%
rbf_df.head(1)
# Out:
#                  mean_test_score  mean_train_score param_svc__gamma  \
# rank_test_score
# 1                       0.621092          0.841597              1.0
#
#                 param_svc__C  mean_fit_time
# rank_test_score
# 1                        1.0       0.100325

# %%
plot = alt.Chart(rbf_df, title="Validation Score for Different Parameters for RBF SVM").mark_line().encode(
    x=alt.X('param_svc__C', title='C (log scale)', scale=alt.Scale(type='log')),
    y=alt.Y('mean_test_score', title='Validation Score').scale(zero=False),
    color=alt.Color('param_svc__gamma:O', title='gamma').scale(scheme='tableau20')
)

plot + alt.Chart(rbf_df.head(1)).mark_text(dy=-5).encode(
    x='param_svc__C',
    y="mean_test_score",
    text=alt.value('Max'))
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Based on the above findings, we have found that in terms of validation score, the best parameters for decision tree is to use gini as the criterion and a `max_depth` of 128, that for linear SVM is to set `C` as 0.1, and that for RBF SVM is to set both `gamma` and `C` as 1.0. We now use these three best models on the test set to assess their performances.

# %%
best_dt_pipe = make_pipeline(StandardScaler(), DecisionTreeClassifier(criterion='gini', max_depth=128))
best_lsvm_pipe = make_pipeline(StandardScaler(), SVC(kernel='linear', C=0.1))
best_rbf_pipe = make_pipeline(StandardScaler(), SVC(gamma=1.0, C=1.0))

best_dt_pipe.fit(X_train, y_train)
best_lsvm_pipe.fit(X_train, y_train)
best_rbf_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('svc', SVC(gamma=1.0))])

# %%
best_dt_pipe.score(X_test, y_test)
# Out:
# 0.6

# %%
best_lsvm_pipe.score(X_test, y_test)
# Out:
# 0.6145833333333334

# %%
best_rbf_pipe.score(X_test, y_test)
# Out:
# 0.6666666666666666

# %% [markdown]
# Among all three models, RBF SVM is the best in terms of test set performance.

# %% [markdown]
# ## Discussion

# %% [markdown]
# Based on the accuracy we've obtained there is no good way to use machine learning algorithm to predict wine quality. These features

# %% [markdown]
# ## References

# %% [markdown]
# 1. https://archive.ics.uci.edu/dataset/186/wine+quality
# 2. http://www3.dsi.uminho.pt/pcortez/wine/
# 3. https://www.thebusinessresearchcompany.com/report/red-wine-global-market-report#:~:text=The%20global%20red%20wine%20market%20size%20grew%20from%20%24102.97%20billion,least%20in%20the%20short%20term.
